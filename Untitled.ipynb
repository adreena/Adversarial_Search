# %%
import pickle
from pprint import pprint
with open('./data.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
pprint(b)
# Out:
# defaultdict(<class 'collections.Counter'>,
#             {('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 0, None, 1): Counter({22: 1,
#                                                                                                                                                            29: 1,
#                                                                                                                                                            94: 1,
#                                                                                                                                                            27: -1,
#                                                                                                                                                            101: -1,
# ...

# %%
pprint(b)
# Out:
# {('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 0, None, 1): 22,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 1, None, 1): 65,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 2, None, 1): 96,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 4, None, 1): 110,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', None, None, 0): 104,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 3, None, 1): 28,
#  ('1111111111100111111111110011111111111001111111111100111111111110011111111111001111111111100111111111110011111111111', 5, None, 1): 40,
# ...
